# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

lat = []
lng = []
city_id = []
wind = []
hum = []
max_tmp = []
country = []
cloudiness = []
city_name = []
date = []

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        hum.append(response['main']['temp'])
        max_tmp.append(response['main']['temp_max'])
        country.append(response['sys']['country'])
        city_id.append(response['id'])
        city_name.append(response['name'])
        date.append(response['dt'])
        #print(f"Processing {cities[city]} | {city}")
    except: KeyError 
        
       #print(f"No data returnd for " {city}: "skipping.")
        
        
    
    print(city)
# Out:
# hithadhoo
# ilam
# vaini
# alice springs
# abha
# leshukonskoye
# airai
# nisia floresta
# minot
# mar del plata
# bambous virieux
# kloulklubed
# shostka
# mokshan
# goderich
# cape town
# new norfolk
# hambantota
# torit
# inhambane
# asyut
# rikitea
# huejuquilla el alto
# ribeira grande
# kapaa
# castro
# tsihombe
# hirara
# atuona
# thompson
# nikolskoye
# celestun
# russell
# san javier
# bathsheba
# adre
# kyren
# busselton
# kavaratti
# tiksi
# nizhneyansk
# cedar city
# taolanaro
# albany
# kuhestan
# tuktoyaktuk
# saleaula
# punta arenas
# vardo
# saint-philippe
# barrow
# mahebourg
# vavoua
# upernavik
# talnakh
# hobart
# vila velha
# kaitangata
# camacha
# karaton
# manali
# east london
# hermanus
# carnarvon
# guisa
# chiman
# galesong
# fort nelson
# akdepe
# kodiak
# baghdad
# bluff
# beloha
# chuy
# flinders
# bandarbeyla
# puerto ayora
# mys shmidta
# yellowknife
# camacupa
# mataura
# nanortalik
# ushuaia
# tasiilaq
# sakakah
# tongliao
# dikson
# bengkulu
# bethel
# navolato
# vostok
# bredasdorp
# georgetown
# belgaum
# pemangkat
# la palma
# ostrovnoy
# sentyabrskiy
# goya
# alexandria
# palu
# lipari
# olafsvik
# yulara
# hasaki
# qasigiannguit
# mugumu
# lagdo
# berlevag
# mount isa
# luderitz
# geraldton
# suzun
# barentsburg
# batagay-alyta
# chapais
# hilo
# kununurra
# teguldet
# port alfred
# tiarei
# salalah
# norman wells
# cidreira
# sembe
# khuzdar
# quatre cocos
# baiyin
# tabiauea
# jamestown
# moose factory
# cabo san lucas
# amapa
# hoa binh
# arraial do cabo
# cap malheureux
# ponta do sol
# mogadishu
# kaka
# alofi
# khonuu
# butaritari
# khatanga
# cam ranh
# mount pleasant
# belushya guba
# zlobin
# yerbogachen
# golden
# wegrow
# raudeberg
# chino valley
# kaeo
# kalmunai
# los llanos de aridane
# asfi
# boyolangu
# fukue
# uzhur
# axim
# mersing
# illoqqortoormiut
# nouadhibou
# yakima
# lagoa
# esperance
# makakilo city
# vestmannaeyjar
# victoria
# sinegorye
# ancud
# grand river south east
# chokurdakh
# umm lajj
# hailar
# temba
# pochutla
# marcona
# tautira
# severo-kurilsk
# nishihara
# zhigansk
# wajir
# asau
# santa rosa
# onega
# salihli
# caconda
# gat
# alibag
# isangel
# coahuayana
# chaumont
# sitka
# yar-sale
# chulym
# khash
# bilibino
# avarua
# coquimbo
# yankton
# bouar
# namatanai
# bembereke
# qiongshan
# amderma
# torbay
# santa maria
# vaitupu
# tiznit
# bud
# cherskiy
# mayumba
# awbari
# puerto narino
# xingyi
# san ramon de la nueva oran
# ambovombe
# gigmoto
# vagur
# prachuap khiri khan
# komatipoort
# karratha
# lebu
# ligayan
# nadym
# panjab
# saint george
# parkersburg
# te anau
# cortez
# acarau
# qaanaaq
# lincoln
# kamenskoye
# praia da vitoria
# reitz
# souillac
# fortuna
# fort saint john
# nelson bay
# makhinjauri
# pangnirtung
# pevek
# xifeng
# traralgon
# pisco
# samalaeulu
# otterup
# noumea
# sangar
# ambilobe
# attawapiskat
# fuerte olimpo
# safaga
# sorvag
# hamilton
# ferrol
# kavieng
# gari
# jalu
# radaur
# rodrigues alves
# opobo
# arlit
# kondinskoye
# balykshi
# ahuimanu
# hervey bay
# mandsaur
# grindavik
# salym
# saskylakh
# severodvinsk
# luanda
# hovd
# lakatoro
# saint-pierre
# puerto leguizamo
# kyzyl-suu
# krasnoye
# zarechnyy
# uglovoye
# ahipara
# clarence town
# katsuura
# san rafael
# bayburt
# codrington
# ahtopol
# morwa
# bosaso
# shelburne
# klaksvik
# mizdah
# saldanha
# port elizabeth
# vestmanna
# griffith
# nguiu
# iqaluit
# anadyr
# nantucket
# pandan
# zaplyusye
# long beach
# megion
# belaya gora
# tayu
# kovdor
# halalo
# port hardy
# lorengau
# kitimat
# kruisfontein
# xining
# rosa zarate
# katunino
# piacabucu
# filotion
# mount gambier
# ludvika
# totma
# rio verde de mato grosso
# kashi
# portland
# surab
# rorvik
# brae
# coihaique
# santa cruz
# markova
# moshny
# lompoc
# antofagasta
# rabat
# chihuahua
# pacific grove
# opelika
# kenora
# north platte
# kazalinsk
# carutapera
# wattegama
# coracora
# tahe
# malanje
# lata
# ekibastuz
# marion
# aquin
# auki
# kirakira
# arua
# sao joao da barra
# sanchor
# las cruces
# morgantown
# lazaro cardenas
# yantal
# melchor de mencos
# garachine
# kijang
# gizo
# bara
# sayaxche
# beya
# sartell
# urdzhar
# arman
# ternate
# shadrinsk
# wangaratta
# margate
# terrace
# milton
# la rioja
# candido mendes
# moron
# cassilandia
# irbit
# altay
# tuatapere
# sokoni
# jining
# saint-augustin
# zanjan
# turukhansk
# coxim
# roma
# mvuma
# iisalmi
# borodino
# saint-felicien
# khagaul
# buy
# sao filipe
# price
# kalabo
# ciudad dario
# kuanshan
# campos gerais
# havre-saint-pierre
# nizwa
# paradwip
# tumannyy
# juneau
# ilulissat
# flin flon
# kozhva
# pallasovka
# ilheus
# san cristobal
# cayenne
# kalengwa
# ulladulla
# touros
# dum duma
# talakan
# aloleng
# bonavista
# shimoda
# lasa
# mocambique
# genhe
# taunggyi
# mackenzie
# grand gaube
# smithers
# santa isabel do rio negro
# tingi
# altamira
# tutoia
# omsukchan
# sorland
# marystown
# birjand
# port hedland
# port shepstone
# alpena
# eenhana
# nakhon ratchasima
# algiers
# namibe
# bolshiye klyuchishchi
# ossora
# boatlaname
# galle
# aklavik
# omboue
# channel-port aux basques
# latina
# ksenyevka
# barcelos
# comodoro rivadavia
# saint-georges
# nkan
# ko samui
# nago
# severo-yeniseyskiy
# kadykchan
# sahrak
# sainte-maxime
# winnemucca
# gwadar
# korla
# khani
# sunrise manor
# san patricio
# lerwick
# kisangani
# yuli
# aasiaat
# benemerito de las americas
# bedford
# tura
# san quintin
# rungata
# evensk
# cheremukhovo
# progreso
# kahului
# vilyuysk
# kurduvadi
# nuuk
# majdanpek
# la uribe
# gamba
# rocha
# bolungarvik
# podosinovets
# sisimiut
# perth
# homer
# skibbereen
# acapulco
# betioky
# mezen
# straubing
# longyearbyen
# hobyo
# bubaque
# labytnangi
# craig
# narsaq
# cururupu
# ilfracombe
# kabare
# kutno
# baruun-urt
# loubomo
# porto walter
# atasu
# dengzhou
# belchatow
# mehamn
# cabedelo
# luba
# sandviken
# anloga
# ereymentau
# aflu
# pokhara
# fakel
# otane
# bentiu
# havoysund
# sudislavl
# torrington
# maykain
# nemuro
# kansay
# huazolotitlan
# sibolga
# olesnica
# turayf
# kedougou
# diffa
# worland
# tarudant
# sur
# port augusta
# fairview
# payakumbuh
# san carlos de bariloche
# talgar
# lengshuitan
# pauini
# guiratinga
# benghazi
# batagay
# burica
# andevoranto
# tonantins
# khovu-aksy
# pervomayskiy
# necochea
# pundaguitan
# clyde river
# kerki
# vao
# meadow lake
# tungor
# carmen
# virginia beach
# provideniya
# lavrentiya
# sorong
# bull savanna
# forbes
# emba
# joshimath
# vaijapur
# atar
# katha
# patea
# luganville
# manono
# faanui
# bose
# barda
# baker city
# maturin
# aquiraz
# aksum
# husavik
# cairns
# lakota
# mandalgovi
# ha giang
# aripuana
# beyneu
# leningradskiy
# aranos
# erzin
# magadi
# athabasca
# blonduos
# qabis
# maracaibo
# richards bay
# boende
# santa catarina de tepehuanes
# candawaga
# entre rios
# kyshtovka
# bida
# shubarshi
# vigrestad
# dudinka
# bay roberts
# barcelona
# samusu
# guerrero negro
# moussoro
# dubovskoye
# verkhnevilyuysk
# sananduva
# maniitsoq
# hay river
# surt
# haines junction
# todos santos
# hokitika
# kosonsoy
# odweyne
# yumen
# andra
# knyaginino
# yuanping
# guntakal

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City Name": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": hum,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": max_tmp,
    "Wind Speed": wind
    
}

weather_df = pd.DataFrame(weather_dict)

weather_df.head()
# Out:
#        City Name  Cloudiness Country        Date  Humidity  Latitude  \
# 0      Hithadhoo           2      MV  1579751221     84.72     -0.60
# 1           Ilam           2      NP  1579751221     44.98     26.92
# 2          Vaini          40      TO  1579750973     82.40    -21.20
# 3  Alice Springs          36      AU  1579751221    100.40    -23.70
# 4           Abha          75      SA  1579751222     52.66     18.22
#
#    Longitude  Max Temperature  Wind Speed
# 0      73.08            84.72       16.24
# 1      87.92            44.98        2.66
# 2    -175.20            82.40       13.87
# 3     133.88           100.40        9.17
# 4      42.51            53.60        9.17

# %%
south_forgets = weather_df.loc[weather_df["Latitude"]<= 0, :]

south_forgets.head()
# Out:
#         City Name  Cloudiness Country        Date  Humidity  Latitude  \
# 0       Hithadhoo           2      MV  1579751221     84.72     -0.60
# 2           Vaini          40      TO  1579750973     82.40    -21.20
# 3   Alice Springs          36      AU  1579751221    100.40    -23.70
# 6           Airai          95      TL  1579751204     82.51     -8.93
# 7  Nisia Floresta          40      BR  1579751222     80.60     -6.09
#
#    Longitude  Max Temperature  Wind Speed
# 0      73.08            84.72       16.24
# 2    -175.20            82.40       13.87
# 3     133.88           100.40        9.17
# 6     125.41            82.51        4.45
# 7     -35.21            80.60        8.05

# %%
north_remembers = weather_df.loc[weather_df["Latitude"] >= 0, :]


north_remembers.head()
# Out:
#         City Name  Cloudiness Country        Date  Humidity  Latitude  \
# 1            Ilam           2      NP  1579751221     44.98     26.92
# 4            Abha          75      SA  1579751222     52.66     18.22
# 5   Leshukonskoye          98      RU  1579751222     21.61     64.90
# 8           Minot          90      US  1579751125     20.12     48.23
# 11    Kloulklubed          75      PW  1579751223     82.40      7.04
#
#     Longitude  Max Temperature  Wind Speed
# 1       87.92            44.98        2.66
# 4       42.51            53.60        9.17
# 5       45.76            21.61        9.53
# 8     -101.30            23.00        4.70
# 11     134.26            82.40       13.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.scatter(weather_df[["Latitude"]], weather_df[["Max Temperature"]], marker="o", color="green")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.scatter(weather_df[["Latitude"]], weather_df[["Humidity"]], marker="o", color="green")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.scatter(weather_df[["Latitude"]], weather_df[["Cloudiness"]], marker="o", color="green")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.title("City Latitude vs. Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.scatter(weather_df[["Latitude"]], weather_df[["Wind Speed"]], marker="o", color="green")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_remembers['Latitude']
y_values = north_remembers['Max Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_forgets['Latitude']
y_values = south_forgets['Max Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
